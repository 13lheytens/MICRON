# %%
import numpy as np
import pandas as pd

# %%
data_dir = '../../data/'

prescriptions_df = pd.read_csv(data_dir + 'PRESCRIPTIONS.csv')
prescriptions_df
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTDATE  \
# 0        2214776           6   107064         NaN  2175-06-11 00:00:00
# 1        2214775           6   107064         NaN  2175-06-11 00:00:00
# 2        2215524           6   107064         NaN  2175-06-11 00:00:00
# 3        2216265           6   107064         NaN  2175-06-11 00:00:00
# 4        2214773           6   107064         NaN  2175-06-11 00:00:00
# ...          ...         ...      ...         ...                  ...
# 4156445  3996662       98887   121032    238144.0  2144-09-06 00:00:00
# 4156446  3996070       98887   121032    238144.0  2144-09-06 00:00:00
# 4156447  3996063       98887   121032    238144.0  2144-09-06 00:00:00
# ...

# %%
print('Total number of patients:     ', len(prescriptions_df.SUBJECT_ID.unique()))
print('Patients with multiple visits:', (prescriptions_df.groupby('SUBJECT_ID').HADM_ID.nunique() > 1).sum())
# Out:
# Total number of patients:      39363
# Patients with multiple visits: 6515

# %%
diag_df = pd.read_csv(data_dir + 'DIAGNOSES_ICD.csv')
diag_df
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0         1297         109   172335      1.0     40301
# 1         1298         109   172335      2.0       486
# 2         1299         109   172335      3.0     58281
# 3         1300         109   172335      4.0      5855
# 4         1301         109   172335      5.0      4254
# ...        ...         ...      ...      ...       ...
# 651042  639798       97503   188195      2.0     20280
# 651043  639799       97503   188195      3.0     V5869
# 651044  639800       97503   188195      4.0     V1279
# 651045  639801       97503   188195      5.0      5275
# 651046  639802       97503   188195      6.0      5569
#
# [651047 rows x 5 columns]

# %%
len(diag_df.SUBJECT_ID.unique())
# Out:
# 46520

# %%
proc_df = pd.read_csv(data_dir + 'PROCEDURES_ICD.csv')
proc_df
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM  ICD9_CODE
# 0          944       62641   154460        3       3404
# 1          945        2592   130856        1       9671
# 2          946        2592   130856        2       3893
# 3          947       55357   119355        1       9672
# 4          948       55357   119355        2        331
# ...        ...         ...      ...      ...        ...
# 240090  228330       67415   150871        5       3736
# 240091  228331       67415   150871        6       3893
# 240092  228332       67415   150871        7       8872
# 240093  228333       67415   150871        8       3893
# 240094  228334       67415   150871        9       3722
#
# [240095 rows x 5 columns]

# %%
len(proc_df.SUBJECT_ID.unique())
# Out:
# 42214
